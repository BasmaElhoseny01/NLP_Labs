# %%
# Write your names In this cell
Student_1 = "Ahmed Hany Farouk Tawfik"
Student_2 = "Basma Hatem Farid Elhoseny"

# %% [markdown]
# # Sentiment Analysis
# In this requirement, you will implement a sentiment analyser using twitter data. We will do it using two classifiers: Logistic Regression and Naive Bayes. Your goal will be to learn how to extract features from tweets and use sklearn to train and test your classifiers.
# Let's get started:

# %%
import nltk
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples 
from utils import process_tweet, build_freqs

# %%
# download the dataset from nltk
nltk.download('twitter_samples')

# stop words are common words that we don't want to include in our features
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to C:\Users\Ahmed-
# [nltk_data]     Laptop\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\twitter_samples.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Ahmed-
# [nltk_data]     Laptop\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [markdown]
# # Prepare the train and test sets

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')
# split the data into two pieces, one for training and one for testing (validation set) 
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg 
test_x = test_pos + test_neg

print(len(train_x))
print(len(test_x))
# Out:
# 8000
# 2000

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (8000, 1)
# test_y.shape = (2000, 1)

# %% [markdown]
# # Utility Functions
# You are given a utils.py file that contains two functions.
# The first one takes a tweet and preprocess it by doing cleaning, tokenization and stemming.
# The second one builds a dictionary with the keys are a tuple of (word, label) and the values are the count of this tuple in the dataset.
#
# It is preferred that you open this file and understand these functions as we will use them next.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 11337

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# # Requirement 1: Logistic Regression
# To predict the sentiment using logistic Regression, we need a way to transform the tweet to numberic features to be able to do the matrix multiplication of logistic regression.
#
# ## Feature Extraction
# We will extract two features from the tweets:
# 1. The first feature is the number of positive words in a tweet
# 2. The second feature is the number of negative words in a tweet
#
# ### extract_features function
# This function takes a tweet then preprocess it to get the words the it should use the freqs dictionary to calculate the positive feature and the negative feature. If a word is positive and its count in the freqs dictionary is 50 then the tweet positive feature should be increased by 50. If a word doesn't exist in the freqs dictionary then you can consider the count as zero.

# %%
def extract_features(tweet, freqs):
    '''
    Input: 
        tweet: the text of a tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,2)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    precessed_tweet = process_tweet(tweet)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 2)) 
    
    ############################## DONE: Calculate positive and negative features ##################################
    
    # loop through each word in the list of words
    for word in precessed_tweet:
    
        
        # increment the word count for the positive label 1
        if (word,1) in freqs.keys():
            x[0][0] += freqs[(word,1)]
        
        
        # increment the word count for the negative label 0
        if (word,0) in freqs.keys():
            x[0][1] += freqs[(word,0)]
        
        
    #################################################################################################################
    assert(x.shape == (1, 2))
    return x

# %%
# Test Your function
tmp1 = extract_features(train_x[0], freqs)

assert (tmp1 - np.array([[3020,   61]])).sum() == 0, "Feature Extraction Error"

# %%
def input_tweets_to_features(tweets, freqs):
    """
    This function takes the tweets as strings and extracts the features for every tweet
    
    Input: 
    - tweets: list of strings (tweets)
    - freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    
    Returns:
    - X: numpy array of shape (len(tweets), 2) 
    """
    
    X = np.zeros((len(tweets), 2))
    
    ################################### DONE: calculate each tweet feature vector and store it in X ###################
    for i, tweet in enumerate(tweets):
        X[i] = extract_features(tweet, freqs)
    
    
    ###################################################################################################################
    
    return X

# %%
X = input_tweets_to_features(train_x, freqs)
Y = train_y

print(X.shape)
print(Y.shape)
# Out:
# (8000, 2)
# (8000, 1)

# %% [markdown]
# ## Logistic Regression
# In this part, we will use sklearn logistic regression model to train and test our logistic regression model

# %%
from sklearn.linear_model import LogisticRegression

# %%
def train_lr(X, Y):
    """
    This function trains logistic regression model
    
    Inputs:
    - X: training data
    - Y: labels
    
    Returns:
    - logistic regression model after training
    """
    
    lr = LogisticRegression(random_state=5)
    
    ################################# DONE: train the lr model (hint: check fit from sklearn) #####################
    lr.fit(X, Y)
    
    ###############################################################################################################
    
    return lr

# %%
lr = train_lr(X, Y.reshape(len(Y),))

assert (lr.coef_ - np.array([[0.00903432, -0.01027023]])).sum() < 1e-6, "Training Error"
assert lr.intercept_[0] - 0.99980174 < 1e-7, "Training Error"

# %%
def predict(clf, X):
    """
    This function takes a classification model and input features to predict their labels
    
    Inputs:
    - clf: classifier trained by sklearn
    - X: input matrix of shape (TweetsDataCount, NFeatures)
    
    Returns:
    - Y_pred: prediction matrix of shape(TweetsDataCount,)
    """
    
    Y_pred = None
    ######################### DONE: predict labels (hint: check predict function from sklearn) ############################
    Y_pred = clf.predict(X)
    #######################################################################################################################
    return Y_pred

# %%
X_test = input_tweets_to_features(test_x, freqs)
Y_test = test_y

print(X_test.shape)
print(Y_test.shape)
# Out:
# (2000, 2)
# (2000, 1)

# %%
Y_pred = predict(lr, X_test)
print(Y_pred.shape)
# Out:
# (2000,)

# %% [markdown]
# ## Let's test our model

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      1000
#          1.0       0.99      0.99      0.99      1000
#
#     accuracy                           0.99      2000
#    macro avg       0.99      0.99      0.99      2000
# weighted avg       0.99      0.99      0.99      2000

# %% [markdown]
# # Requirement 2: Naive Bayes
# As you know, naive bayes is based on words frequencies. To train a Naive Bayes classifier we need to do the following:
#
# ## 1. Bag of Words:
# We need to represent each tweet with a vector of size V where V is the size of vocabulary and each entry represents the count of the word at this index. For this we will use the count vectorizer of sklearn
#
# ## 2. Train Naive Bayes:
# Training the Multinomial Naive Bayes needs the matrix that represents the documents as bag of words.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
def preprocess_for_CountVectorizer(corpus):
    """
    This function takes list of documents and preprocess them for CountVectorizer
    
    Inputs:
    - corpus: List of strings
    
    Returns:
    - processed_corpus: List of strings
    """
    processed_corpus = None
    ################################# DONE: implement the following steps ####################################
    
    # preprocess tweets (you should have a list of lists since you will call process_tweet on all tweets)
    processed_corpus = [process_tweet(tweet) for tweet in corpus]
    
    
    # append the tokens of each tweet together seperating them by white space
    # As the CountVectorizer needs list of strings
    # hint: check str.join()
    processed_corpus = [' '.join(tokens).lower() for tokens in processed_corpus]

    
    ##########################################################################################################
    
    return processed_corpus

# %%
NB_processed_train_x = preprocess_for_CountVectorizer(train_x)
NB_processed_test_x = preprocess_for_CountVectorizer(test_x)

assert len(train_x) == len(NB_processed_train_x), "Processing Error"
assert len(test_x) == len(NB_processed_test_x), "Processing Error"
assert NB_processed_train_x[0] == 'followfriday top engag member commun week :)', "Processing Error"

# %%
def train_count_vectorizer(processed_train_corpus):
    """
    This function takes processed training corpus and trains a CountVectorizer
    
    Inputs:
    - processed_train_corpus: list of tweets
    
    Returns:
    - vectorizer: CountVectorizer Object after training
    """
    
    vectorizer = None
    ################################### DONE: Create and Fit the vectorizer ##################################
    # Create the Vectorizer
    # hint1: check CountVectorizer from sklearn
    # hint2: You will need to specify the token_pattern parameter as the default one will miss some tokens
    # vectorizer = CountVectorizer(token_pattern=r'\s.+\s')
    vectorizer = CountVectorizer(token_pattern=r'\b\w\w+\b')
    # vectorizer = CountVectorizer(token_pattern=r'\b[^\d\W]+\b')
    
    
    # fit the vectorizer
    # Fit the data (this is where it actually counts the words)
    vectorizer.fit(processed_train_corpus)
    
    ##########################################################################################################
    
    return vectorizer

# %%
BoWVectorizer = train_count_vectorizer(NB_processed_train_x)
train_x_BOW = BoWVectorizer.transform(NB_processed_train_x)
test_x_BOW = BoWVectorizer.transform(NB_processed_test_x)
assert len(BoWVectorizer.vocabulary_) == 9083, "Count Vectorizer Error"
assert train_x_BOW.shape == (8000, 9083), "Count Vectorizer Error"
assert test_x_BOW.shape == (2000, 9083), "Count Vectorizer Error"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# e:\college\CMP Fourth Year\Natural Language Processing\Labs\github\NLP_Labs\Lab 3 - Text Classification\Sentiment Analysis.ipynb Cell 30 line 4
#       <a href='vscode-notebook-cell:/e%3A/college/CMP%20Fourth%20Year/Natural%20Language%20Processing/Labs/github/NLP_Labs/Lab%203%20-%20Text%20Classification/Sentiment%20Analysis.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> train_x_BOW = BoWVectorizer.transform(NB_processed_train_x)
#       <a href='vscode-notebook-cell:/e%3A/college/CMP%20Fourth%20Year/Natural%20Language%20Processing/Labs/github/NLP_Labs/Lab%203%20-%20Text%20Classification/Sentiment%20Analysis.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a> test_x_BOW = BoWVectorizer.transform(NB_processed_test_x)
# ----> <a href='vscode-notebook-cell:/e%3A/college/CMP%20Fourth%20Year/Natural%20Language%20Processing/Labs/github/NLP_Labs/Lab%203%20-%20Text%20Classification/Sentiment%20Analysis.ipynb#X41sZmlsZQ%3D%3D?line=3'>4</a> assert len(BoWVectorizer.vocabulary_) == 9083, "Count Vectorizer Error"
#       <a href='vscode-notebook-cell:/e%3A/college/CMP%20Fourth%20Year/Natural%20Language%20Processing/Labs/github/NLP_Labs/Lab%203%20-%20Text%20Classification/Sentiment%20Analysis.ipynb#X41sZmlsZQ%3D%3D?line=4'>5</a> assert train_x_BOW.shape == (8000, 9083), "Count Vectorizer Error"
#       <a href='vscode-notebook-cell:/e%3A/college/CMP%20Fourth%20Year/Natural%20Language%20Processing/Labs/github/NLP_Labs/Lab%203%20-%20Text%20Classification/Sentiment%20Analysis.ipynb#X41sZmlsZQ%3D%3D?line=5'>6</a> assert test_x_BOW.shape == (2000, 9083), "Count Vectorizer Error"
#
# AssertionError: Count Vectorizer Error

# %%
import emoji

def is_emoji(s):
    return s in emoji.emojize(s) != s

# # your set
# s = {"Hello", "🙂", "World", "🌎"}



x = set()
[x.update(set(l)) for l in [string.split(' ') for string in NB_processed_train_x]]
print(x)
print(len(x))
# new set without emojis
x = {i for i in x if not is_emoji(i)}
q = set()
q2 = set()
for x1 in x:
    print(x1, end='\n')
    # check if it is number
    if x1.isdigit():
        q2.add(x1)
        continue
    q.add(x1)

print(len(x))
print(len(q))
print(q2)
# Out:
# {'', 'fiesta', 'esp', 'pokemon', 'soph', 'aint', 'seungchan', "emily'", 'closet', 'jailbroken', 'dancer', 'done', 'iqrar', 'stolen', 'bam', 'pliss', 'meth', 'classmat', 'batch', 'mehendi', 'dollar', "mine'", 'pilllow', 'strap', 'goodnight', 'lyk', 'duck', 'halsey', 'egg', 'timetunnel', 'aaahh', 'abbymil', 'takeaway', 'happend', 'friendship', 'block', 'warm-up', 'monash', 'kunoriforceo', 'vike', 'dobar', 'uber', 'hunt', 'pie', 'ken', 'construct', 'mine', 'hii', 'eek', 'nathann', '50p', 'extraordinari', "it'okay", 'obstacl', 'excit', 'pain', 'renew', 'sobtian', 'sim', 'popcorn', 'daisi', 'hyung', 'citizen', 'megamoh', '58543', 'mist', 'auto-followback', 'e', 'siregar', ';-)', 'unreal', 'vega', 'pair', 'cakehamp', 'sugarrush', 'smf', 'tramlin', 'wing', 'desper', 'when', 'trouser', 'nou', '24/7', 'longest', '5h', 'bugbounti', 'yongb', 'prima', 'backup', 'luxembourg', 'slovenia', 'assess', 'em-con', 'hang', 'neat-o', 'bebii', '2hr', 'tagal', 'speed', 'jiba', 'countthecost', 'dah', 'vein', 'blain', 'spars', 'patriot', 'otherwis', 'cuz', 'powder', 'nigg', 'finalist', 'sinhala', 'yayayayay', 'wewanticecream', 'glacier', 'film', 'deepxcap', 'bilal', 'choreo', 'system', '30juli', 'corner', 'damn', 'degre', 'insidi', 'waist', 'lukkke', 'worri', 'tommi', 'papertown', '48id', 'goictiv', 'العنزي', 'melon', 'safer', 'popular', 'getwellsoonamb', 'chan', 'kinick', 'non-mapbox', 'sleeep', 'geneva', 'sorri', 'mino', 'zayncomebackto', 'pll', 'obama', 'yeaaah', 'kiksext', 'kei', 'claim', 'along', 'pre-season', 'cantik', 'b2c', 'display', '01482', 'chronic', 'sadomasochist', 'endow', 'socent', 'paddock', 'couch', 'bo3', ':-(', 'thoo', '404', 'agonis', 'ignor', 'kw', 'marco', 'bed', 'freebiefriday', 'katerina', 'yr', 'findyourfit', 'bbz', 'gyu', 'deliri', 'loveofmylif', 'followingg', 'festiv', 'merri', 'allerg', 'gomen', '🙏🏻', 'fank', 'politician', 'shape', 'opix', 'viber', 'vegetarian', '18c', 'usual', 'klappertart', 'aaj', 'nois', 'fear', 'cumshot', 'hsould', 'chrompet', 'player', 'zzz', 'softbal', '200', 'inbox', 'big', 'wakeup', 'oop', "pixar'", 'se100lead', 'honour', 'prettiest', 'fugiwara', '1190', 'miracl', 'yummm', 'vertigo', 'poison', 'wavi', 'presid', 'subcontin', 'initi', '0ne', 'introduc', 'where.do.i.start', 'transpar', 'gift', 'ouucchhh', 'abroad', 'shop', '🌷', 'feet', 'erm', 'listen', 'walnut', 'jojo', 'wealth', 'cayton', 'prepar', 'what', 'greatest', 'choregraph', 'selfshot', 'kidney', 'elsa', 'derbi', 'tour', 'chronicl', 'ligo', "demi'", 'teenag', 'taissa', 'ure', 'challo', 'thingi', "ain't", 'hyungbot', 'itter', 'lemon', 'bigtim', '15th', 'acorn', 'on-pack', "it'll", 'jame', '✧', 'foodi', 'x29', 'lot', '♛', 'ig', 'nell', 'beb', 'chikka', 'burn', "lassi'", 'pleasant', 'wayn', 'bohat', 'k3g', 'gensan', 'flat', 'tub', 'bh3', '11', 'kaha', 'itti', 'imsorri', 'sequel', 'said', 'tla', 'banter', "millie'", 'agre', 'fback', '5minut', 'xxx', 'pussycat', 'debut', 'pant', 'lui', '6g', 'advaddict', 'explor', 'fabian', 'spray', 'monster', 'enix', 'constantli', 'coupl', 'kandekj', 'signatur', '💪', 'selamat', 'teaser', 'misspelt', 'horrif', 'delph', 'katekyn', 'possibl', 'rumor', 'xavier', '💞', 'greatli', 'finddjderek', 'plan', 'vault', 'machineri', 'harumph', 'ramzan', 'tini', 'unhappi', 'stick', 'skrillah', 'knit', 'toe', 'convers', 'avoplex', 'kelli', 'regen', 'tank', 'background', 'blue', 'hmmm', 'auto-focu', 'emot', 'leicaq', 'dress', 'alumni', 'bailey', 'bruuh', 'allow', 'offens', 'jest', 'shaylan', 'leas', 'cocoar', 'oe', 'tx', 'word', 'brows', 'elfindelmundo', 'raid', 'movi', 'religion', 'woot', 'finland', 'chip', 'tou', 'ayemso', 'nth', 'loool', 'carriageway', 'nuka', '35', 'walmart', 'insomnia', 'starbuck', 'grab', 'definit', 'folder', 'mcfc', 'bebee', 'ramadhan', '3rd', 'trace', 'cold', 'brow', 'yt', 'randomli', '🌃', 'vv', 'legal', 'ariana', 'poor', 'erit', 'zap', 'darcey', 'nation', 'platon', 'dovey', 'ifc', 'cpu', 'fingers-cross', 'nah', 'ash', 'grew', 'abligaverin', 'nez', 'hahahahahhaha', 'scale', 'govern', 'thehungergam', 'provok' ...
# 9086
#
# fiesta
# esp
# pokemon
# soph
# emily'
# jailbroken
# iqrar
# stolen
# bam
# meth
# classmat
# strap
# mine'
# pilllow
# duck
# egg
# timetunnel
# happend
# friendship
# block
# warm-up
# kunoriforceo
# vike
# dobar
# pie
# hii
# eek
# nathann
# 50p
# it'okay
# renew
# citizen
# 58543
# megamoh
# mist
# vega
# tramlin
# sugarrush
# junmyeon
# desper
# smf
# nou
# longest
# trouser
# 5h
# bugbounti
# yongb
# luxembourg
# em-con
# neat-o
# hang
# bebii
# speed
# jiba
# spars
# dah
# otherwis
# powder
# finalist
# yayayayay
# wewanticecream
# deepxcap
# film
# bilal
# system
# 30juli
# insidi
# lukkke
# tommi
# العنزي
# popular
# getwellsoonamb
# chan
# kinick
# sleeep
# sorri
# pll
# yeaaah
# kei
# claim
# along
# pre-season
# cantik
# b2c
# display
# chronic
# sadomasochist
# endow
# :-(
# thoo
# ignor
# katerina
# findyourfit
# deliri
# 🙏🏻
# opix
# klappertart
# aaj
# nois
# cumshot
# chrompet
# zzz
# softbal
# big
# pixar'
# fugiwara
# 1190
# vertigo
# poison
# wavi
# presid
# subcontin
# initi
# 0ne
# where.do.i.start
# transpar
# gift
# abroad
# 🌷
# feet
# erm
# jojo
# cayton
# prepar
# derbi
# tour
# chronicl
# ligo
# demi'
# teenag
# ure
# ain't
# hyungbot
# lemon
# bigtim
# 15th
# acorn
# on-pack
# rememb
# 1hr
# ndi
# instruct
# ramd
# edwin
# jersey
# stereo
# yulin
# scar
# asia
# sunggyu
# qatarday
# awuuu
# heart-break
# luxurytravel
# clap
# dagga
# wrong
# report
# 󾆖
# mcfloat
# dampen
# cramp
# tomorrowland
# philippa
# januari
# robyn
# privat
# latmon
# treat
# sublimin
# subj
# idek
# pothol
# konga
# balik
# flipkartfashionfriday
# whoooah
# skate
# prelim
# hear
# afang
# health
# nun
# deleici
# youth@bipolaruk.org.uk
# happybirthday
# brilliant
# bob
# goodmorn
# nearer
# mapbox
# pale
# schoolwork
# know
# pe
# whhr
# sumedh
# hater
# poc
# long-dist
# int
# understand
# singer
# stronger
# keedz
# unprepar
# gaaawd
# sanza
# rider
# remot
# 😵
# lay
# french
# she
# bio
# nash
# month
# bye
# back
# grim
# choma
# extrem
# 💃🏽
# potato
# gave
# 31st
# safaa
# diane'
# bc
# mileag
# unavail
# laomma
# debbi
# zayniscomingback
# hogo
# violenc
# swasa
# accommod
# tear
# stiff
# carmen
# stat
# koe
# valentin
# fruit
# 👉
# peter
# pb.contest
# robert'
# mushroom
# iflix
# beograd
# hotti
# mixer
# pa-copi
# nknkkpagpapakumbaba
# enterprison
# entrepreneurship
# gain
# fwm
# sf
# ross
# dmme
# lure
# chao
# bat
# midori
# necessari
# sara
# loos
# wowza
# arummzz
# --->
# mubarak
# leak
# cushion
# justinbieb
# burger
# assingn
# 1k
# salabrati
# quickest
# 120
# av
# rod
# shoushitsu
# l
# deya
# rape
# green
# float
# cheeki
# argo
# anyon
# doomsday
# whaaat
# jeb
# upload
# greymind
# taknottem
# good
# mare
# caradelevingn
# doodl
# doom
# collab
# bend
# doushit
# pl
# alhamdullilah
# volunt
# 737bigatingconcert
# server
# ripaaa
# forget
# “
# taal
# anal
# cough
# nhl
# 😭
# unblock
# nudg
# tooth
# cpm
# nugget
# beyt
# pearson
# non
# 20
# toni
# everlast
# resort
# sync
# network
# tooo
# coffe
# cnblue
# magazin
# shave
# candl
# asthma
# throwbackfriday
# wynter
# amnot
# callie'
# sick
# akshaymostlovedsuperstarev
# recip
# comp
# decis
# inatal
# norapowel
# posti
# ☕
# sandcastl
# hih
# qui
# lib
# uggghhh
# tag
# emyu
# internet
# prinsesa
# fantasi
# eye
# entlead
# yaa
# dirti
# center
# campu
# cost
# blackberri
# assur
# flint
# bantim
# sosweet
# tick
# corinehurleigh
# boss
# senpai
# tmw
# buset
# shek
# mein
# fave
# canal
# real_liam_payn
# 2fm
# lc
# anarchi
# sister-in-law
# bright
# img
# suggest
# staff
# amassiveoverdoseofship
# maker
# video
# march
# crappl
# tearout
# jail
# vidcon
# ausfailia
# carrot
# x
# likeforlik
# seat
# botani
# atchya
# cheapest
# nintendo
# bother
# mashup
# likeforfollow
# meant
# 336
# leed
# suspems
# 63
# af
# sorna
# truli
# ...
# pube
# low
# scene
# blooper
# mjhe
# ireland
# o_o
# kikhorni
# voucher
# chose
# syru
# mari
# discharg
# growl
# yall
# garbi
# classi
# furbabi
# photoshoot
# hallow
# carol
# comic
# medit
# zayniscomingbackonjuli
# vicki
# 01282
# kumbl
# imo
# yūjō-cosplay
# xi
# mandela
# mba
# kfc
# aw
# ftw
# empow
# calum
# well
# daal
# seafood
# hushedcallwithfraydo
# patric
# pleasee
# bang
# fu
# journo
# protect
# beirut
# stare
# neither
# ty
# noon
# nawf
# nerd
# main
# how'r
# hazel
# skoy
# ce
# bg
# gta
# ladyposs
# wet
# sorta
# issu
# chop
# hairpin
# tiredashel
# grepein
# hoki
# bu
# situat
# retali
# enemi
# despair
# caught
# beginn
# impress
# confess
# puffi
# thurston
# glaze
# lock
# korean
# 765
# shall
# diva
# videogam
# exist
# n
# criticis
# sian
# approv
# problemat
# eintlik
# 68
# uniform
# exhaust
# imitatia
# url
# hungrrryyi
# jurass
# activ
# redeem
# opinion
# hyungwon
# للحياة
# maxfreshmov
# crap
# ralli
# x42
# bet
# 9086
# 8902
# {'13', '98', '886', '42', '323', '4000', '345', '62', '22', '677', '322', '34', '348', '1645', '344', '08', '40', '12', '100', '343', '506', '87', '444', '3000', '120', '337', '805', '336', '3306', '7', '4', '325', '338', '9', '640', '0345', '25', '1', '333505', '748292', '63', '477', '43', '59', '58543', '08962464174', '321', '479', '70685', '2016', '330', '340', '335', '911', '320', '16', '80', '19', '23', '35', '797', '482', '823', '565', '0330', '590', '452096', '0', '60', '600', '328', '10', '697', '423', '329', '490', '123', '891', '76', '02079', '000', '61', '1033', '334', '332', '009', '500', '317', '72', '430', '2017', '0878', '70', '101', '1982', '30', '1948', '01482', '01282', '404', '50', '20', '3', '547', '24', '609', '132', '00962778381', '14518344', '319', '300', '12000', '26', '877', '27', '2009', '156', '0272', '331', '28', '454', '15', '90210', '200', '18', '2', '6', '838', '1900', '510', '1190', '64', '8', '642', '5', '350', '74', '324', '873', '874', '150', '47', '65', '327', '85552', '14', '468', '316', '2013', '33', '765', '111', '15000', '02392441234', '91', '700', '68', '17', '346', '349', '342', '333', '0388', '318', '7234', '51', '2015', '48', '73', '1400', '326', '32429', '1000', '21', '31', '339', '00128835', '95', '341', '11', '45', '00', '347', '39'}

# %%
len(BoWVectorizer.vocabulary_)
# Out:
# 8648

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
def train_NB(X, Y):
    """
    This function takes the document frequency matrix (BoW matrix) and trains a MultinomialNB
    
    Inputs:
    - X: Document frequency matrix
    - Y: the labels
    Returns:
    - MultinomialNB Classifier
    """
    
    NB = None
    ############################## TODO: create and train Add-one Smoothed NB Classifer #############################
    # Create the NB classifier (hint: check MultinomialNB sklearn documentation for add-one smoothnig)
    
    
    # train
    
    ##################################################################################################################
    return NB

# %%
NB = train_NB(train_x_BOW, train_y.reshape(len(train_y),))

assert NB.classes_[1] == 1, "NB Error"
assert NB.class_log_prior_[1] - -0.69314718 < 1e-8, "NB Error"
assert NB.class_count_[1] == 4000, "NB Error"

# %%
Y_pred = predict(NB, test_x_BOW)
print(Y_pred.shape)

# %% [markdown]
# # Let's test the NB model

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
